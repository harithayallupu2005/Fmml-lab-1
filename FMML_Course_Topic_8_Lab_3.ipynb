# %% [markdown]
# <a href="https://colab.research.google.com/github/harithayallupu2005/Fmml-lab-1/blob/main/FMML_Course_Topic_8_Lab_3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Bayesian Machine Learning: Lab 3 - Applying Bayes Classifiers

# %% [markdown]
# Lab by V Vijay Vignesh
#
# vijay.vignesh@research.iiit.ac.in

# %%
import os
import json
import re

import numpy as np
import pandas as pd

from matplotlib import pyplot as plt
import seaborn as sns
import plotly.express as px
import plotly.graph_objects as pg

import tensorflow as tf
import tensorflow_probability as tfp

# %%
# !wget https://raw.githubusercontent.com/Foundations-in-Modern-Machine-Learning/course-contents/main/Bayesian/data/arxiv-paper-data.json
plt.style.use('ggplot')
# Out:
# --2024-03-31 09:44:10--  https://raw.githubusercontent.com/Foundations-in-Modern-Machine-Learning/course-contents/main/Bayesian/data/arxiv-paper-data.json
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.108.133, 185.199.109.133, 185.199.110.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 72422946 (69M) [text/plain]
# Saving to: ‘arxiv-paper-data.json’
#
# arxiv-paper-data.js 100%[===================>]  69.07M   110MB/s    in 0.6s
#
# 2024-03-31 09:44:13 (110 MB/s) - ‘arxiv-paper-data.json’ saved [72422946/72422946]

# %% [markdown]
# Let's make a few assumptions to come up with our first general model for classification:
# * The different features contribute equally to the result
# * The features are independent

# %% [markdown]
# ## Bayes Classifiers in Scikit Learn

# %% [markdown]
# ### Simple 1-D Classfication using Naive Bayes in Continuous Space

# %%
fig, ax = plt.subplots(figsize=(18, 8))
x1 = np.random.normal(1.0, 0.3, size=5000)
x2 = np.random.normal(0.0, 0.3, size=50000)
x = np.concatenate([x1, x2])
y = np.concatenate([np.zeros(len(x1)), np.ones(len(x2))])
sns.histplot(x1, color='blue', alpha=0.5, ax=ax)
sns.histplot(x2, color='red', alpha=0.5, ax=ax)
ax.fill_between(np.linspace(-1.0, 0.7, 100), 0, 1800,  color='r', alpha=0.1)
ax.fill_between(np.linspace(0.7, 2.0, 100), 0, 1800,  color='b', alpha=0.1)
ax.vlines(0.5, 0, 1750, color="k", linestyles="--", lw=3)
ax.vlines(0.7, 0, 1750, color="g", linestyles="--", lw=3)
ax.scatter(x1, [np.random.randint(2000, 3000) for _ in x1], color='b', s=1)
ax.scatter(x2, [np.random.randint(2000, 3000) for _ in x2], color='r', s=1)
ax.set_xlim(-1.0, 2.0)
ax.set_ylim(0, 3200)
plt.show()

# %%
from sklearn.naive_bayes import GaussianNB
gnb = GaussianNB()
x_reshaped = x.reshape(1, -1)
print(x_reshaped.shape)
# Out:
# (1, 55000)

# %% [markdown]
# ## Gaussian Bayes Predictor on Predicting Flowers

# %% [markdown]
# ### Predictors in Scikit Learn

# %%
from sklearn.datasets import load_iris
from sklearn.model_selection import train_test_split
from sklearn.naive_bayes import GaussianNB

X, y = load_iris(return_X_y=True)
X = X[:, [2, 3]]
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.5, random_state=0)
gnb = GaussianNB()
gnb.fit(X_train, y_train)
# Out:
# GaussianNB()

# %%
plt.figure(figsize=(20, 10))
color_scheme = ['red', 'green', 'blue']
plt.scatter(X_train[:, 0], X_train[:, 1], c=[color_scheme[idx] for idx in y_train])
plt.show()

# %% [markdown]
# ### Visualizing the Decision Surface

# %%
plt.figure(figsize=(20, 10))
X1_scan, X2_scan = np.meshgrid(np.linspace(0.5, 7.5, 250), np.linspace(0.0, 3.0, 250))
X_scan = np.stack([np.reshape(X1_scan, -1), np.reshape(X2_scan, -1)], axis=-1)
predictions = gnb.predict(X_scan)
color_map = ['r', 'g', 'b']
plt.scatter(x=X_test[:, 0], y=X_test[:, 1], c=[color_map[x] for x in y_test])
sns.kdeplot(x=X_scan[:, 0], y=X_scan[:, 1], hue=[color_map[x] for x in predictions], fill=False)
plt.show()

# %% [markdown]
# ## Bayes on Text - Classifying papers at Arxiv

# %% [markdown]
# ### Data Cleaning and Preprocessing

# %%
arxiv_df = pd.read_json(open("arxiv-paper-data.json", 'r'))
arxiv_df["tag"] = arxiv_df["tag"].apply(lambda x: json.loads(x.replace("\'", "\"").replace("None", "\"None\""))[0]['term'].split('.')[0])
arxiv_df["tag"] = arxiv_df["tag"].apply(lambda x: 'physics' if x in ['physics', 'quant-ph', 'astro-ph', 'hep-ex', 'hep-ph', 'hep-lat', 'hep-th', 'nucl-th'] else x)
arxiv_df = arxiv_df.drop(["day", "month", "link", "author"], axis=1)

# %%
SAMPLES_COMP = 3500 #@param {type: "slider", min: 1000, max: 4500}
SAMPLES_STAT = 2500 #@param {type: "slider", min: 1000, max: 4500}
WORD_COUNT_THRESHOLD = 1  #@param {type: "slider", min: 1, max: 500}
WORD_LENGTH_THRESHOLD = 8  #@param {type: "slider", min: 4, max: 20}

# %%
df = pd.concat([arxiv_df[arxiv_df['tag'] == 'cs'].sample(SAMPLES_COMP, replace=False),
                arxiv_df[arxiv_df['tag'] == 'stat'].sample(SAMPLES_STAT, replace=False)]).sample(frac=1)
df['keywords'] = df.apply(lambda x: [word.lower() for word in re.sub('[^(\w| )]', '', re.sub('(-|_|\n)', ' ', x.summary + ' ' + x.title)).split()
                                     if len(word) > WORD_LENGTH_THRESHOLD and not re.search('(\d|\(|\))', word)], axis=1)
train_df, test_df = df.iloc[:int(len(df) * 0.8)], df.iloc[int(len(df) * 0.8):]

train_df
# Out:
#                  id                                            summary   tag  \
# 23891   1207.7244v1  In this technical report, we review related wo...    cs
# 16229  1611.00674v9  A synonym of a polysemous word is usually only...    cs
# 7315   1711.09195v1  Feature selection can facilitate the learning ...  stat
# 21381  1801.08650v1  An intelligent robot agent based on domain ont...    cs
# 40260  1802.09975v1  Monocular cameras are one of the most commonly...    cs
# ...             ...                                                ...   ...
# 2190   1705.03562v1  We present a new deep meta reinforcement learn...  stat
# 21730   1210.8429v1  Given a time series of graphs G(t) = (V, E(t))...  stat
# 19877   1303.1498v1  Bayesian belief networks can be used to repres...    cs
# 28932  1708.00786v1  Foreground map evaluation is crucial for gaugi...    cs
# 23283   1011.6656v2  This paper introduces a new method for learnin...    cs
#
#                                                    title  year  \
# 23891  Visual Vocabulary Learning and Its Application...  2012
# 16229  Fuzzy paraphrases in learning word representat...  2016
# 7315   Feature Selection Facilitates Learning Mixture...  2017
# 21381  Ontology-based Fuzzy Markup Language Agent for...  2018
# 40260  Mono-Camera 3D Multi-Object Tracking Using Dee...  2018
# ...                                                  ...   ...
# 2190   Deep Episodic Value Iteration for Model-based ...  2017
# 21730  Anomaly Detection in Time Series of Graphs usi...  2012
# 19877  GALGO: A Genetic ALGOrithm Decision Support To...  2013
# 28932  Structure-measure: A New Way to Evaluate Foreg...  2017
# 23283           Learning sparse representations of depth  2010
#
#                                                 keywords
# 23891  [technical, vocabulary, recognition, retrieval...
# 16229  [polysemous, paraphrase, representations, para...
# 7315   [selection, facilitate, variables, crowdsourci...
# 21381  [intelligent, mechanism, presented, establishe...
# 40260  [monocular, automotive, autonomous, monocular,...
# ...                                                  ...
# 2190   [reinforcement, iteration, similarity, paramet...
# 21730  [represents, represents, existence, communicat...
# 19877  [represent, uncertain, incomplete, conflicting...
# 28932  [foreground, evaluation, segmentation, algorit...
# 23283  [introduces, inferring, representations, algor...
#
# [4800 rows x 6 columns]

# %%
df['keywords']
# Out:
# 23891    [technical, vocabulary, recognition, retrieval...
# 16229    [polysemous, paraphrase, representations, para...
# 7315     [selection, facilitate, variables, crowdsourci...
# 21381    [intelligent, mechanism, presented, establishe...
# 40260    [monocular, automotive, autonomous, monocular,...
#                                ...
# 33411    [experimental, algorithms, population, attract...
# 14149    [algorithm, efficient, optimization, solutions...
# 25823    [segmentation, segmentation, conditional, stru...
# 7528     [recurrent, excellent, performance, applicatio...
# 11258    [introduce, variational, alternative, variatio...
# Name: keywords, Length: 6000, dtype: object

# %% [markdown]
# ### Learning Probability Distributions

# %%
from collections import defaultdict
dictionary = defaultdict(lambda: [0, 0])
for desc, tag in zip(df['keywords'], df['tag']):
    for word in set(desc):
        if tag == 'cs':
            dictionary[word][0] += 1
        else:
            dictionary[word][1] += 1

print("We have a dictionary of", len(dictionary), "words.")

words, counts_cs, counts_stat = [], [], []
for word, count in dictionary.items():
    if count[0] + count[1] > WORD_COUNT_THRESHOLD:
        words.append(word)
        counts_cs.append(count[0])
        counts_stat.append(count[1])
print("Out of those", len(words), f"have over {WORD_COUNT_THRESHOLD} occurances")

fig = pg.Figure([pg.Bar(x=words[:200], y=counts_cs[:200]),
                 pg.Bar(x=words[:200], y=counts_stat[:200])])
fig.update_layout(title_text=f'Some random words and the frequency plot of those with over {WORD_COUNT_THRESHOLD} occurances')
fig.show()
# Out:
# We have a dictionary of 8859 words.
# Out of those 4592 have over 1 occurances
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="3e13f3a0-ca71-479e-b20f-0b10419df38b" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("3e13f3a0-ca71-479e-b20f-0b10419df38b")) {                    Plotly.newPlot(                        "3e13f3a0-ca71-479e-b20f-0b10419df38b",                        [{"x":["representation","retrieval","recognition","vocabulary","descriptor","application","optimization","technical","conventional","coefficient","outperforms","unreliable","eliminated","experimental","polysemous","alleviate","paraphrase","experiments","paraphrases","reliability","representations","according","empirically","information","improvement","distributions","structured","crowdsourcing","statistical","algorithm","facilitate","validated","intuitively","generally","facilitates","selection","variables","introduce","substantial","justified","assistant","difficulty","knowledge","meanwhile","increased","mechanism","performance","mathematical","presented","intelligent","established","concentration","furthermore","available","filtering","associations","dimensional","autonomous","monocular","performing","algorithms","bernoulli","detections","accurately","combination","automotive","developing","evaluated","coordinates","efficient","benchmark","observations","correctly","coordinate","trajectories","generative","supervised","respectively","unlabeled","conditionally","conditional","framework","discriminators","significantly","demonstrate","distribution","attributes","situations","diagonalization","incorporated","explicitly","distributedly","expensive","investigated","structure","partitions","terminate","calculation","techniques","approximate","complicated","implementation","effective","environments","particular","subsampled","thoroughly","difficult","bottleneck","direction","communication","synchronization","stochastic","distributed","consumption","estimation","measurements","nonnegative","quadratically","extensive","recovering","individual","factorization","motivated","effectiveness","synthetic","autocorrelation","objective","quadratic","constrained","relaxation","electricity","illustrate","aggregates","realistic","comparable","intelligence","improvements","generating","discriminator","simulation","understanding","achieving","predicting","forecasting","recurrent","interesting","generator","adversarial","artificial","sequences","transformations","competitively","generation","reasoning","contextual","prediction","underlying","ultimately","disaggregation","laboratory","spatiotemporal","characteristics","dynamical","exploring","generated","involving","quantifying","programming","validating","integration","technique","dependency","dependencies","subsequently","developed","renewable","identifying","residential","different","collection","extremely","practitioners","challenge","reductions","metropolis","frequency","magnitude","inference","development","comparison","implemented","maintaining","asynchronous","attempted","proportional","processing","leverages","contributions","differential"],"y":[339,98,371,34,36,228,317,48,115,22,273,13,8,390,5,17,8,590,4,22,219,85,82,686,155,122,105,14,142,828,40,35,14,68,20,158,113,336,39,11,3,47,369,20,32,115,902,55,187,54,65,8,183,302,68,16,194,51,22,70,576,4,19,64,143,5,68,150,11,398,214,73,39,19,25,110,200,92,43,1,101,573,4,274,570,211,56,49,1,17,71,0,66,51,339,14,4,24,375,116,30,130,255,70,284,3,10,151,15,54,63,8,120,101,22,198,46,11,0,183,23,118,41,59,225,111,3,133,30,61,24,4,82,8,68,106,94,109,108,13,72,172,72,77,18,158,58,34,99,149,92,52,5,159,111,47,208,106,8,1,9,13,79,21,35,168,47,9,123,5,48,257,47,48,16,204,2,81,2,699,66,65,11,155,5,3,51,57,208,121,141,100,24,7,6,12,295,31,48,22],"type":"bar"},{"x":["representation","retrieval","recognition", ...

# %% [markdown]
# For each word, for both the subjects, we can apply Bayes rule.
#
# $$P\bigg(\frac{\text{subject}}{\text{word}}\bigg) = P\bigg(\frac{\text{word}}{\text{subject}}\bigg) \times \frac{P(\text{subject})}{P(\text{word})}$$

# %% [markdown]
# ### Computing the resultant probabilities

# %%
prior = np.array([train_df["tag"].value_counts()["cs"], train_df["tag"].value_counts()["stat"]]) / len(train_df)
evidence = np.array([counts_cs / train_df["tag"].value_counts()["cs"], counts_stat / train_df["tag"].value_counts()["stat"]]).T
likelihood = (np.array(counts_cs) + np.array(counts_stat)) / len(train_df)

prior.shape, likelihood.shape, evidence.shape
# Out:
# ((2,), (4592,), (4592, 2))

# %%
words_to_index = defaultdict(lambda: -1)
for idx, word in enumerate(words):
    words_to_index[word] = idx

correct, total = 0, 0

answers = []
for tag, keywords in zip(test_df["tag"], test_df["keywords"]):
    this_counts = np.zeros(len(words))
    for word in keywords:
        idx = words_to_index[word]
        if idx != -1:
            this_counts[idx] = 1

    marginal = np.multiply(prior.T, np.divide(
        np.multiply(this_counts.reshape(-1, 1), evidence), likelihood.reshape(-1, 1))) + 0.001
    joint = np.sum(np.log(marginal), axis=0)
    predicted = 'cs' if joint[0] > joint[1] else 'stat'
    answers.append(predicted)
    if predicted == tag:
        correct += 1
    total += 1
test_df.insert(1, "predictions", answers, True)

print("Accuracy:", correct / total)
# Out:
# Accuracy: 0.81

# %% [markdown]
# ### Visualizing a few examples

# %%
def explain(example):
    from IPython.display import HTML
    title, desc, answer = example["title"], example["summary"], example["tag"]
    html = ""
    title = re.sub(' +', ' ', re.sub('[^(\w| )]', '', re.sub('(-|_|\n)', ' ', title)))
    desc = re.sub(' +', ' ', re.sub('[^(\w| )]', '', re.sub('(-|_|\n)', ' ', desc)))
    for text in [title, desc]:
        for word in text.split():
            idx = words_to_index[word.lower()]
            if idx == -1:
                html += f"<span style=''>{word}</span> "
            else:
                posterior = np.multiply(evidence[idx], prior)
                posterior /= np.sum(posterior)
                if posterior[0] > posterior[1] if answer == 'cs' else (posterior[0] <= posterior[1]):
                    color = max(0.3, posterior[0] - posterior[1])
                    html += f"<span style='background-color:rgba(0, 255, 0, {color});'>{word}</span> "
                else:
                    color = max(0.3, posterior[1] - posterior[0])
                    html += f"<span style='background-color:rgba(255, 0, 0, {color});'>{word}</span> "
        html += "<br/><br/>"
    return HTML(html)

# %%
x = test_df[np.logical_and(test_df["predictions"] == test_df["tag"], test_df["tag"] == "cs")].iloc[0]
explain(x)
# Out:
# <span style=''>An</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>efficient</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>algorithm</span> <span style=''>for</span> <span style=''>learning</span> <span style=''>with</span> <span style=''>semi</span> <span style=''>bandit</span> <span style=''>feedback</span> <br/><br/><span style=''>We</span> <span style=''>consider</span> <span style=''>the</span> <span style=''>problem</span> <span style=''>of</span> <span style=''>online</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>combinatorial</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>optimization</span> <span style=''>under</span> <span style=''>semi</span> <span style=''>bandit</span> <span style=''>feedback</span> <span style=''>The</span> <span style=''>goal</span> <span style=''>of</span> <span style=''>the</span> <span style=''>learner</span> <span style=''>is</span> <span style=''>to</span> <span style='background-color:rgba(255, 0, 0, 0.37499999999999994);'>sequentially</span> <span style=''>select</span> <span style=''>its</span> <span style=''>actions</span> <span style=''>from</span> <span style=''>a</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>combinatorial</span> <span style=''>decision</span> <span style=''>set</span> <span style=''>so</span> <span style=''>as</span> <span style=''>to</span> <span style=''>minimize</span> <span style=''>its</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>cumulative</span> <span style=''>loss</span> <span style=''>We</span> <span style=''>propose</span> <span style=''>a</span> <span style=''>learning</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>algorithm</span> <span style=''>for</span> <span style=''>this</span> <span style=''>problem</span> <span style=''>based</span> <span style=''>on</span> <span style='background-color:rgba(0, 255, 0, 0.34567901234567905);'>combining</span> <span style=''>the</span> <span style=''>Follow</span> <span style=''>the</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>Perturbed</span> <span style=''>Leader</span> <span style=''>(FPL)</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>prediction</span> <span style=''>method</span> <span style=''>with</span> <span style=''>a</span> <span style=''>novel</span> <span style=''>loss</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>estimation</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>procedure</span> <span style=''>called</span> <span style='background-color:rgba(0, 255, 0, 0.3148148148148149);'>Geometric</span> <span style='background-color:rgba(255, 0, 0, 0.5789473684210527);'>Resampling</span> <span style=''>(GR)</span> <span style=''>Contrary</span> <span style=''>to</span> <span style=''>previous</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>solutions</span> <span style=''>the</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>resulting</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>algorithm</span> <span style=''>can</span> <span style=''>be</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>efficiently</span> <span style='background-color:rgba(0, 255, 0, 0.38888888888888884);'>implemented</span> <span style=''>for</span> <span style=''>any</span> <span style=''>decision</span> <span style=''>set</span> <span style=''>where</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>efficient</span> <span style=''>offline</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>combinatorial</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>optimization</span> <span style=''>is</span> <span style=''>possible</span> <span style=''>at</span> <span style=''>all</span> <span style=''>Assuming</span> <span style=''>that</span> <span style=''>the</span> <span style=''>elements</span> <span style=''>of</span> <span style=''>the</span> <span style=''>decision</span> <span style=''>set</span> <span style=''>can</span ...

# %%
x = test_df[np.logical_and(test_df["predictions"] == test_df["tag"], test_df["tag"] == "stat")].iloc[0]
explain(x)
# Out:
# <span style='background-color:rgba(0, 255, 0, 0.3);'>Rademacher</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Complexity</span> <span style=''>Bounds</span> <span style=''>for</span> <span style=''>a</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Penalized</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Multiclass</span> <span style=''>Semi</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>Supervised</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>Algorithm</span> <br/><br/><span style=''>We</span> <span style=''>propose</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Rademacher</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>complexity</span> <span style=''>bounds</span> <span style=''>for</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>multiclass</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>classifiers</span> <span style=''>trained</span> <span style=''>with</span> <span style=''>a</span> <span style=''>two</span> <span style=''>step</span> <span style=''>semi</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>supervised</span> <span style=''>model</span> <span style=''>In</span> <span style=''>the</span> <span style=''>first</span> <span style=''>step</span> <span style=''>the</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>algorithm</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>partitions</span> <span style=''>the</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>partially</span> <span style=''>labeled</span> <span style=''>data</span> <span style=''>and</span> <span style=''>then</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>identifies</span> <span style=''>dense</span> <span style=''>clusters</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>containing</span> <span style=''>kappa</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>predominant</span> <span style=''>classes</span> <span style=''>using</span> <span style=''>the</span> <span style=''>labeled</span> <span style=''>training</span> <span style=''>examples</span> <span style=''>such</span> <span style=''>that</span> <span style=''>the</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>proportion</span> <span style=''>of</span> <span style=''>their</span> <span style=''>non</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>predominant</span> <span style=''>classes</span> <span style=''>is</span> <span style=''>below</span> <span style=''>a</span> <span style=''>fixed</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>threshold</span> <span style=''>In</span> <span style=''>the</span> <span style=''>second</span> <span style=''>step</span> <span style=''>a</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>classifier</span> <span style=''>is</span> <span style=''>trained</span> <span style=''>by</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>minimizing</span> <span style=''>a</span> <span style=''>margin</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>empirical</span> <span style=''>loss</span> <span style=''>over</span> <span style=''>the</span> <span style=''>labeled</span> <span style=''>training</span> <span style=''>set</span> <span style=''>and</span> <span style=''>a</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>penalization</span> <span style=''>term</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>measuring</span> <span style=''>the</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>disability</span> <span style=''>of</span> <span style=''>the</span> <span style=''>learner</span> <span style=''>to</span> <span style=''>predict</span> <span style=''>the</span> <span style=''>kappa</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>predominant</span> <span style=''>classes</span> <span style=''>of</span> <span style=''>the</span> <span style='background-color:rgba(255, ...

# %%
x = test_df[np.logical_and(test_df["predictions"] != test_df["tag"], test_df["tag"] == "cs")].iloc[0]
explain(x)
# Out:
# <span style=''>Finite</span> <span style=''>Time</span> <span style=''>Analysis</span> <span style=''>of</span> <span style=''>Kernelised</span> <span style='background-color:rgba(0, 255, 0, 0.40298507462686567);'>Contextual</span> <span style=''>Bandits</span> <br/><br/><span style=''>We</span> <span style=''>tackle</span> <span style=''>the</span> <span style=''>problem</span> <span style=''>of</span> <span style=''>online</span> <span style=''>reward</span> <span style='background-color:rgba(255, 0, 0, 0.33333333333333337);'>maximisation</span> <span style=''>over</span> <span style=''>a</span> <span style=''>large</span> <span style=''>finite</span> <span style=''>set</span> <span style=''>of</span> <span style=''>actions</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>described</span> <span style=''>by</span> <span style=''>their</span> <span style=''>contexts</span> <span style=''>We</span> <span style=''>focus</span> <span style=''>on</span> <span style=''>the</span> <span style=''>case</span> <span style=''>when</span> <span style=''>the</span> <span style=''>number</span> <span style=''>of</span> <span style=''>actions</span> <span style=''>is</span> <span style=''>too</span> <span style=''>big</span> <span style=''>to</span> <span style=''>sample</span> <span style=''>all</span> <span style=''>of</span> <span style=''>them</span> <span style=''>even</span> <span style=''>once</span> <span style=''>However</span> <span style=''>we</span> <span style=''>assume</span> <span style=''>that</span> <span style=''>we</span> <span style=''>have</span> <span style=''>access</span> <span style=''>to</span> <span style=''>the</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>similarities</span> <span style=''>between</span> <span style=''>actions</span> <span style=''>contexts</span> <span style=''>and</span> <span style=''>that</span> <span style=''>the</span> <span style=''>expected</span> <span style=''>reward</span> <span style=''>is</span> <span style=''>an</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>arbitrary</span> <span style=''>linear</span> <span style=''>function</span> <span style=''>of</span> <span style=''>the</span> <span style=''>contexts</span> <span style=''>images</span> <span style=''>in</span> <span style=''>the</span> <span style=''>related</span> <span style='background-color:rgba(255, 0, 0, 0.7);'>reproducing</span> <span style=''>kernel</span> <span style=''>Hilbert</span> <span style=''>space</span> <span style=''>(RKHS)</span> <span style=''>We</span> <span style=''>propose</span> <span style=''>KernelUCB</span> <span style=''>a</span> <span style=''>kernelised</span> <span style=''>UCB</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>algorithm</span> <span style=''>and</span> <span style=''>give</span> <span style=''>a</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>cumulative</span> <span style=''>regret</span> <span style=''>bound</span> <span style=''>through</span> <span style=''>a</span> <span style='background-color:rgba(255, 0, 0, 0.8571428571428572);'>frequentist</span> <span style=''>analysis</span> <span style=''>For</span> <span style='background-color:rgba(0, 255, 0, 0.40298507462686567);'>contextual</span> <span style=''>bandits</span> <span style=''>the</span> <span style=''>related</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>algorithm</span> <span style=''>GP</span> <span style=''>UCB</span> <span style=''>turns</span> <span style=''>out</span> <span style=''>to</span> <span style=''>be</span> <span style=''>a</span> <span style=''>special</span> <span style=''>case</span> <span style=''>of</span> <span style=''>our</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>algorithm</span> <span style=''>and</span> <span style=''>our</span> <span style=''>finite</span> <span style=''>time</span> <span style=''>analysis</span> <span style=''>improves</span> <span style=''>the</span> <span style=''>regret</span ...

# %%
x = test_df[np.logical_and(test_df["predictions"] != test_df["tag"], test_df["tag"] == "stat")].iloc[0]
explain(x)
# Out:
# <span style=''>Tree</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Exploration</span> <span style=''>for</span> <span style=''>Bayesian</span> <span style=''>RL</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Exploration</span> <br/><br/><span style=''>Research</span> <span style=''>in</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>reinforcement</span> <span style=''>learning</span> <span style=''>has</span> <span style=''>produced</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>algorithms</span> <span style=''>for</span> <span style=''>optimal</span> <span style=''>decision</span> <span style=''>making</span> <span style=''>under</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>uncertainty</span> <span style=''>that</span> <span style=''>fall</span> <span style=''>within</span> <span style=''>two</span> <span style=''>main</span> <span style=''>types</span> <span style=''>The</span> <span style=''>first</span> <span style=''>employs</span> <span style=''>a</span> <span style=''>Bayesian</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>framework</span> <span style=''>where</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>optimality</span> <span style=''>improves</span> <span style=''>with</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>increased</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>computational</span> <span style=''>time</span> <span style=''>This</span> <span style=''>is</span> <span style=''>because</span> <span style=''>the</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>resulting</span> <span style=''>planning</span> <span style=''>task</span> <span style=''>takes</span> <span style=''>the</span> <span style=''>form</span> <span style=''>of</span> <span style=''>a</span> <span style=''>dynamic</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>programming</span> <span style=''>problem</span> <span style=''>on</span> <span style=''>a</span> <span style=''>belief</span> <span style=''>tree</span> <span style=''>with</span> <span style=''>an</span> <span style=''>infinite</span> <span style=''>number</span> <span style=''>of</span> <span style=''>states</span> <span style=''>The</span> <span style=''>second</span> <span style=''>type</span> <span style=''>employs</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>relatively</span> <span style=''>simple</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>algorithm</span> <span style=''>which</span> <span style=''>are</span> <span style=''>shown</span> <span style=''>to</span> <span style=''>suffer</span> <span style=''>small</span> <span style=''>regret</span> <span style=''>within</span> <span style=''>a</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>distribution</span> <span style=''>free</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>framework</span> <span style=''>This</span> <span style=''>paper</span> <span style=''>presents</span> <span style=''>a</span> <span style=''>lower</span> <span style=''>bound</span> <span style=''>and</span> <span style=''>a</span> <span style=''>high</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>probability</span> <span style=''>upper</span> <span style=''>bound</span> <span style=''>on</span> <span style=''>the</span> <span style=''>optimal</span> <span style=''>value</span> <span style=''>function</span> <span style=''>for</span> <span style=''>the</span> <span style=''>nodes</span> <span style=''>in</span> <span style=''>the</span> <span style=''>Bayesian</span> <span style=''>belief</span> <span style=''>tree</span> <span style=''>which</span> <span style=''>are</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>analogous</span> <span style=''>to</span> <span style=''>similar</span> <span style=''>bounds</span> <span style=''>in</span> <span style=''>POMDPs</span> <span style=''>The</span> <span style=''>bounds</span> <span style=''>are ...

# %% [markdown]
# ### Visualizing the Learnt Words

# %%
print("Some Computer Science words are:")
for word_cs in np.argsort(evidence[:, 0] - evidence[:, 1])[-10:]:
    print(f"\t{words[word_cs]} ({evidence[word_cs, 0]})")
print()
print("Some Statistics words are:")
for word_st in np.argsort(evidence[:, 1] - evidence[:, 0])[-10:]:
    print(f"\t{words[word_st]} ({evidence[word_st, 1]})")
# Out:
# Some Computer Science words are:
# 	information (0.24300389656393906)
# 	challenging (0.09847679773290825)
# 	knowledge (0.13071200850159406)
# 	segmentation (0.06730428622033298)
# 	experimental (0.1381509032943677)
# 	architecture (0.08537017357421182)
# 	different (0.24760892667375134)
# 	detection (0.13637973786751684)
# 	recognition (0.1314204746723344)
# 	convolutional (0.136733970952887)
#
# Some Statistics words are:
# 	stochastic (0.13353566009104703)
# 	estimation (0.16742539200809306)
# 	statistical (0.15123925139099645)
# 	algorithm (0.39706626201315126)
# 	variables (0.14618108244815378)
# 	theoretical (0.1638846737481032)
# 	distribution (0.18664643399089528)
# 	dimensional (0.18512898330804248)
# 	regression (0.17754172989377845)
# 	inference (0.20890237733940314)

# %% [markdown]
# ## Probability Smoothing
#
# Probability smoothing is a language modeling technique that assigns some non-zero probability to events that were unseen in the training data. This has the effect that the probability mass is divided over more events, hence the probability distribution becomes more smooth.

# %% [markdown]
# ### Realizing the Problem

# %%
posterior = np.multiply(np.divide(evidence, np.reshape(likelihood, (-1, 1))), np.reshape(prior, (1, -1)))

fig = pg.Figure([pg.Bar(x=words, y=evidence[:20, 0]),
                 pg.Bar(x=words, y=posterior[:20, 0])])
fig.update_layout(title_text='Evidence and Posterior for each word')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="e89cd432-9496-4a5f-a18a-9638a3a247b5" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("e89cd432-9496-4a5f-a18a-9638a3a247b5")) {                    Plotly.newPlot(                        "e89cd432-9496-4a5f-a18a-9638a3a247b5",                        [{"x":["representation","retrieval","recognition","vocabulary","descriptor","application","optimization","technical","conventional","coefficient","outperforms","unreliable","eliminated","experimental","polysemous","alleviate","paraphrase","experiments","paraphrases","reliability","representations","according","empirically","information","improvement","distributions","structured","crowdsourcing","statistical","algorithm","facilitate","validated","intuitively","generally","facilitates","selection","variables","introduce","substantial","justified","assistant","difficulty","knowledge","meanwhile","increased","mechanism","performance","mathematical","presented","intelligent","established","concentration","furthermore","available","filtering","associations","dimensional","autonomous","monocular","performing","algorithms","bernoulli","detections","accurately","combination","automotive","developing","evaluated","coordinates","efficient","benchmark","observations","correctly","coordinate","trajectories","generative","supervised","respectively","unlabeled","conditionally","conditional","framework","discriminators","significantly","demonstrate","distribution","attributes","situations","diagonalization","incorporated","explicitly","distributedly","expensive","investigated","structure","partitions","terminate","calculation","techniques","approximate","complicated","implementation","effective","environments","particular","subsampled","thoroughly","difficult","bottleneck","direction","communication","synchronization","stochastic","distributed","consumption","estimation","measurements","nonnegative","quadratically","extensive","recovering","individual","factorization","motivated","effectiveness","synthetic","autocorrelation","objective","quadratic","constrained","relaxation","electricity","illustrate","aggregates","realistic","comparable","intelligence","improvements","generating","discriminator","simulation","understanding","achieving","predicting","forecasting","recurrent","interesting","generator","adversarial","artificial","sequences","transformations","competitively","generation","reasoning","contextual","prediction","underlying","ultimately","disaggregation","laboratory","spatiotemporal","characteristics","dynamical","exploring","generated","involving","quantifying","programming","validating","integration","technique","dependency","dependencies","subsequently","developed","renewable","identifying","residential","different","collection","extremely","practitioners","challenge","reductions","metropolis","frequency","magnitude","inference","development","comparison","implemented","maintaining","asynchronous","attempted","proportional","processing","leverages","contributions","differential","alternative","structures","increasing","researchers","industrial","thousands","converges","parameter","probabilistic","operators","identified","approaches","assumptions","parametric","requiring","thresholds","resulting","posterior","community","graphical","formulated","detection","computational","typically","expresses","considerably","especially","efficiently","behaviour","temperatures","solutions","principled","estimates","broadening","equations","inhibited","applicability","incorporating","unfortunately","efficiency","unavailable","buildings","aggregation","excellent","architectures","outperformed","predictions","parameters","segmentation","configuration","overfitting","challenging","consistently","a ...

# %%
print("Some words which never appear in Computer Science paper:\n\t" + "\n\t".join([words[idx] for idx in np.where(np.array(counts_cs) == 0)[0][:20]]))
print("Some words which never appear in Statistics papers:\n\t" + "\n\t".join([words[idx] for idx in np.where(np.array(counts_stat) == 0)[0][:20]]))
# Out:
# Some words which never appear in Computer Science paper:
# 	distributedly
# 	quadratically
# 	temperatures
# 	inhibited
# 	replicated
# 	cytometry
# 	normality
# 	streamlined
# 	possessing
# 	elucidate
# 	conveniently
# 	invention
# 	subtleties
# 	abnormally
# 	heteroscedastic
# 	layerwise
# 	forecaster
# 	certificate
# 	governing
# 	unregularized
# Some words which never appear in Statistics papers:
# 	polysemous
# 	paraphrase
# 	paraphrases
# 	assistant
# 	monocular
# 	initiated
# 	solomonoff
# 	enumerable
# 	depthwise
# 	lowdimensional
# 	identities
# 	subsequences
# 	subjected
# 	correspondences
# 	templates
# 	termination
# 	motivations
# 	refutation
# 	epistemological
# 	unacceptable

# %% [markdown]
# Notice the fact that there are cases where the Evidence $P\big(\frac{\text{word}}{\text{subject}}\big) \rightarrow 0$. This is because there are occurances of the given word in the corpus (all the abstract of papers put together) of that subject.
#
# However, this is no way implies that if a word (eg. Employment) never occurs in our training corpus in a Computer Science paper, it will also never occur in a paper in the test set.
#
# Therefore, setting $P(\text{word} | \text{subject}) = 0$ is incorrect, since it will make the posterior $P(\text{subject} | \text{word}) = 0$, even if the corresponding count it 0, we need to come up with a smoother formulation of the Evidence variables.

# %% [markdown]
# ### Laplace Smoothing
#
#
#
# https://towardsdatascience.com/laplace-smoothing-in-na%C3%AFve-bayes-algorithm-9c237a8bdece

# %%
alpha = 0.1
counts_cs, counts_stat = np.array(counts_cs), np.array(counts_stat)
evidence_smooth = np.array([(counts_cs + alpha) / (train_df["tag"].value_counts()["cs"] + alpha * len(words)),
                            (counts_stat + alpha) / (train_df["tag"].value_counts()["stat"] + alpha * len(words))]).T
print(np.min(evidence_smooth))
sns.displot(evidence_smooth)
# Out:
# 3.0467369447321922e-05

# %%
words_to_index = defaultdict(lambda: -1)
for idx, word in enumerate(words):
    words_to_index[word] = idx

correct, total = 0, 0

answers = []
for tag, keywords in zip(test_df["tag"], test_df["keywords"]):
    this_counts = np.zeros(len(words))
    for word in keywords:
        idx = words_to_index[word]
        if idx != -1:
            this_counts[idx] = 1

    marginal = np.multiply(prior.T, np.divide(np.multiply(this_counts.reshape(-1, 1), evidence_smooth), likelihood.reshape(-1, 1))) + 0.0000001
    joint = np.sum(np.log(marginal), axis=0)
    predicted = 'cs' if joint[0] > joint[1] else 'stat'
    answers.append(predicted)
    if predicted == tag:
        correct += 1
    total += 1
test_df.insert(1, "predictions", answers, True)

print("Accuracy:", correct / total)
# Out:
# Accuracy: 0.7633333333333333
